# %% [markdown]
# # Title
#
# Introduction text.

# %%
import os
print(os.getcwd())
# Out:
# /home/user

# %% [markdown]
# ## Section A
#
# Details about section A.

# %%
x = 1
y = 2
print(x + y)
# Out:
# 3

# %% [markdown]
# ## Section B
#
# Details about section B.

# %%
server = "10.0.0.5"
token = "ghp_R2D2c3POxWfYz9AqBmNjKlHgTsUvXw0123"
